# %%
#importing liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
data=pd.read_csv('default_of_credit_card_clients.csv')
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
# first 5 rows
data.head(5)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#last 5 rows 
data.tail(5)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# shape of the dataset
data.shape
print('rows are',data.shape[0])
print('columns are',data.shape[1])
# Out:
# rows are 30000
# columns are 25

# %%
# information of dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
# summary of numerical column
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# check for missing values 
missing_values=data.isnull().sum()
print('missing_values are: ', missing_values)
# Out:
# missing_values are:  ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# checking for the duplicate rows

duplicate_count=data.duplicated().sum()
print('duplicate count',duplicate_count)
# Out:
# duplicate count 0

# %%
# univariate analysis
#countplot for the target variable

sns.countplot(x='default payment next month', data=data)
plt.title("Default Payment Distribution (0 = No, 1 = Yes)")
plt.xlabel("Default Payment Next Month")
plt.ylabel("Count")
plt.show()

# Check class balance in percentage
default_rate = data['default payment next month'].value_counts(normalize=True) * 100
print("Class distribution (%):\n", default_rate)
# Out:
# Class distribution (%):
#  default payment next month
# 0    77.88
# 1    22.12
# Name: proportion, dtype: float64

# %% [markdown]
# **Default Status**	                   **Description	Percentage**
# **0 Did not default (paid dues)	   77.88%
# 1 Defaulted on payment	           22.12%**
#
# # **Insight**:
# **There is a class imbalance in the dataset — only 22.12% of the customers defaulted. This should be considered while modeling, as it can bias predictions toward the majority class (non-defaulters).**

# %%
# categorical features

# Gender Distribution
sns.countplot(x='SEX', data=data)
plt.title("Gender Distribution (1 = Male, 2 = Female)")
plt.show()

# Education Level
sns.countplot(x='EDUCATION', data=data)
plt.title("Education Level Distribution")
plt.show()

# Marital Status
sns.countplot(x='MARRIAGE', data=data)
plt.title("Marital Status Distribution (1 = Married, 2 = Single, 3 = Others)")
plt.show()

# %%
data['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
data['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: count, dtype: int64

# %%
# Replace incorrect values with 4 (others)
data['EDUCATION'] = data['EDUCATION'].replace({0: 4, 5: 4, 6: 4})

# %%
data['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %%
data['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: count, dtype: int64

# %%
data['MARRIAGE']=data['MARRIAGE'].replace({0:3})

# %%
# categorical features

# Gender Distribution
sns.countplot(x='SEX', data=data)
plt.title("Gender Distribution (1 = Male, 2 = Female)")
plt.show()

# Education Level
sns.countplot(x='EDUCATION', data=data)
plt.title("Education Level Distribution (1 = graduate school; 2 = university; 3 = high school; 4 = others)")
plt.show()

# Marital Status
sns.countplot(x='MARRIAGE', data=data)
plt.title("Marital Status Distribution (1 = Married, 2 = Single, 3 = Others)")
plt.show()

# %%
#Bivariate Analysis
# Compare default rate by Gender
sns.countplot(x='SEX', hue='default payment next month', data=data)
plt.title("Default Rate by Gender")
plt.xlabel("Gender (1 = Male, 2 = Female)")
plt.ylabel("Count")
plt.legend(title="Default (1 = Yes)")
plt.show()

# %%
# Compare default rate by Education
sns.countplot(x='EDUCATION', hue='default payment next month', data=data)
plt.title("Default Rate by Education Level")
plt.xlabel("Education Level (1 = Grad School, 2 = University, 3 = High School, 4 = Others)")
plt.ylabel("Count")
plt.legend(title="Default (1 = Yes)")
plt.show()

# %%
# Check and clean marriage column first (some datasets have 0)
#print(df['MARRIAGE'].value_counts())

# Replace 0 (unknown) with 3 (others)
#data['MARRIAGE'] = df['MARRIAGE'].replace(0, 3)

# Plot
sns.countplot(x='MARRIAGE', hue='default payment next month', data=data)
plt.title("Default Rate by Marital Status")
plt.xlabel("Marital Status (1 = Married, 2 = Single, 3 = Others)")
plt.ylabel("Count")
plt.legend(title="Default (1 = Yes)")
plt.show()

# %%
# Select only numerical columns for correlation matrix
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# %%
# Compute correlation matrix
corr_matrix = numeric_data.corr()

# %%
# Plot heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Correlation of features with the target
target_corr = corr_matrix['default payment next month'].sort_values(ascending=False)
print("Top correlations with default payment next month:\n", target_corr.head(10))
# Out:
# Top correlations with default payment next month:
#  default payment next month    1.000000
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# EDUCATION                     0.033842
# AGE                           0.013890
# BILL_AMT6                    -0.005372
# Name: default payment next month, dtype: float64

# %%
# Example: Boxplot to detect outliers
sns.boxplot(x=data['LIMIT_BAL'])
plt.title("Outlier Detection in Credit Limit")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# Drop target temporarily
X = data.drop('default payment next month', axis=1)
y = data['default payment next month']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# Evaluation
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, lr.predict_proba(X_test)[:,1]))
# Out:
# [[4550  137]
#  [1004  309]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      4687
#            1       0.69      0.24      0.35      1313
#
#     accuracy                           0.81      6000
#    macro avg       0.76      0.60      0.62      6000
# weighted avg       0.79      0.81      0.77      6000
#
# ROC AUC Score: 0.7271329962426254

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Create the model
rf_model = RandomForestClassifier(random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Predict on test set
rf_preds = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC AUC

# %%
# Confusion Matrix
print(confusion_matrix(y_test, rf_preds))

# Classification Report
print(classification_report(y_test, rf_preds))

# ROC AUC Score
roc_auc = roc_auc_score(y_test, rf_probs)
print("ROC AUC Score:", roc_auc)
# Out:
# [[4432  255]
#  [ 851  462]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4687
#            1       0.64      0.35      0.46      1313
#
#     accuracy                           0.82      6000
#    macro avg       0.74      0.65      0.67      6000
# weighted avg       0.80      0.82      0.79      6000
#
# ROC AUC Score: 0.7636133129651118

# %%
data.to_csv(r'C:\Users\Sneha\Desktop\CreditRisk\DefaultOfCreditCard.csv', index=False)
